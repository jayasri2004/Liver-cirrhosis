# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/479/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/50/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/5/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/39.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/39.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/506/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/490/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/507/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/393/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/502/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/481/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/4.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/2.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/7.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/5.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/3.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/6.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/4.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/2.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/7.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/5.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/3.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/6.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/53/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/483/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/493/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/512/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/495/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/56/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/498/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/valid/498/images/20.png
# ...
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/31/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/344/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/9.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/8.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/412/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/189/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/37.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/38.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/312/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/35.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/31.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/33.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/36.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/28.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/34.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/29.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/32.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/30.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/114/masks/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/images/26.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/11.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/14.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/20.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/10.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/18.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/21.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/12.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/22.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/17.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/16.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/24.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/23.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/15.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/27.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/13.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/25.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/19.png
# /kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/430/masks/26.png

# %%
# !pip install evaluate
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.12.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (19.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.16)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.13.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.19.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->evaluate) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->evaluate) (2024.2.0)

# %%
import os
import numpy as np
import torch
import cv2
import matplotlib.pyplot as plt
from glob import glob
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from transformers import SegformerImageProcessor, SegformerForSemanticSegmentation
import torch.nn.functional as F
from tqdm.notebook import tqdm
import evaluate

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Enable synchronous CUDA debugging (optional, for debugging GPU issues)
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# Paths to images and masks
image_paths = sorted(glob("/kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/*/images/*.png"))
mask_paths = sorted(glob("/kaggle/input/cirrhosis-corrected/Cirrhosis_T2_2D/train/*/masks/*.png"))
print(f"Total Images: {len(image_paths)}, Total Masks: {len(mask_paths)}")

# Dataset class
class SemanticSegmentationDataset(Dataset):
    def __init__(self, image_paths, mask_paths, image_processor, num_classes=2):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.image_processor = image_processor
        self.num_classes = num_classes

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load grayscale image and convert to 3-channel (Segformer expects RGB)
        image = Image.open(self.image_paths[idx]).convert("L")
        image = np.array(image)
        image = np.stack([image] * 3, axis=-1).astype(np.uint8)  # Stack to create 3 channels
        image = Image.fromarray(image)

        # Load segmentation mask
        mask = Image.open(self.mask_paths[idx])
        mask = np.array(mask, dtype=np.int64)

        # Clean mask values (assuming masks have 0 and 255)
        mask[mask == 255] = 1  # Map 255 to 1 (foreground class)
        mask = np.clip(mask, 0, self.num_classes - 1)  # Ensure values are in [0, num_classes-1]

        # Apply image processor
        encoded_inputs = self.image_processor(image, mask, return_tensors="pt")
        for k, v in encoded_inputs.items():
            encoded_inputs[k].squeeze_()  # Remove batch dimension
        return encoded_inputs

# Image processor
image_processor = SegformerImageProcessor(do_resize=True, size=(512, 512), reduce_labels=False)

# Dataset and DataLoader
train_dataset = SemanticSegmentationDataset(image_paths, mask_paths, image_processor, num_classes=2)
train_dataloader = DataLoader(train_dataset, batch_size=5, shuffle=True)

# Model initialization
num_classes = 2
model = SegformerForSemanticSegmentation.from_pretrained(
    "nvidia/mit-b0",
    num_labels=num_classes,
    ignore_mismatched_sizes=True
).to(device)

# Custom CEDiceLoss definition
class CEDiceLoss(torch.nn.Module):
    def __init__(self, dice_weight=0.5, smooth=1e-6):
        super(CEDiceLoss, self).__init__()
        self.dice_weight = dice_weight  # Weight for Dice Loss vs Cross-Entropy Loss
        self.smooth = smooth  # Smoothing factor to avoid division by zero
        self.ce_loss = torch.nn.CrossEntropyLoss()  # Built-in Cross-Entropy Loss

    def dice_loss(self, logits, targets):
        num_classes = logits.size(1)
        dice = 0
        for c in range(num_classes):
            pred = logits[:, c].sigmoid()  # Apply sigmoid to get probabilities
            true = (targets == c).float()  # One-hot encoding for the class
            intersection = (pred * true).sum()
            union = pred.sum() + true.sum()
            dice += (2. * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice / num_classes  # Return 1 - Dice coefficient as loss

    def forward(self, logits, targets):
        # Upsample logits to match target size
        logits = F.interpolate(logits, size=targets.shape[-2:], mode="bilinear", align_corners=False)
        ce_loss = self.ce_loss(logits, targets)  # Compute Cross-Entropy Loss
        dice_loss = self.dice_loss(logits, targets)  # Compute Dice Loss
        return (1 - self.dice_weight) * ce_loss + self.dice_weight * dice_loss  # Combine losses

# Initialize loss function
loss_fn = CEDiceLoss(dice_weight=0.5).to(device)

# Optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

# Metric for evaluation
metric = evaluate.load("mean_iou")

# Training loop
model.train()
step_counter = 0
losses = []
mean_ious = []
steps = []

for epoch in range(1, 11):  # Train for 10 epochs
    print(f"\nEpoch {epoch}")
    epoch_losses = []
    
    for idx, batch in enumerate(tqdm(train_dataloader)):
        pixel_values = batch["pixel_values"].to(device)
        labels = batch["labels"].to(device)
        
        # Forward pass
        optimizer.zero_grad()
        outputs = model(pixel_values=pixel_values)
        logits = outputs.logits
        loss = loss_fn(logits, labels)
        loss.backward()
        optimizer.step()
        
        epoch_losses.append(loss.item())
        
        # Evaluate every 100 steps
        if idx % 100 == 0:
            with torch.no_grad():
                upsampled_logits = F.interpolate(
                    logits, size=labels.shape[-2:], mode="bilinear", align_corners=False
                )
                predicted = upsampled_logits.argmax(dim=1)
                metric.add_batch(
                    predictions=predicted.detach().cpu().numpy(),
                    references=labels.detach().cpu().numpy()
                )
                metrics = metric.compute(num_labels=num_classes, ignore_index=-100, reduce_labels=False)
                current_iou = metrics['mean_iou']
                
                # Store metrics for plotting
                losses.append(loss.item())
                mean_ious.append(current_iou)
                steps.append(step_counter)
                
                print(f"Step {step_counter} | Loss: {loss.item():.4f} | Mean IoU: {current_iou:.4f}")
        
        step_counter += 1
    
    avg_epoch_loss = sum(epoch_losses) / len(epoch_losses)
    print(f"Epoch {epoch} | Average Loss: {avg_epoch_loss:.4f}")

# Save model weights
torch.save(model.state_dict(), "segformer_model_weights.pth")

# Plot training metrics
plt.figure(figsize=(12, 5))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(steps, losses, '-o', markersize=2, alpha=0.7)
plt.title('Training Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.grid(True, linestyle='--', alpha=0.6)

# Plot Mean IoU
plt.subplot(1, 2, 2)
plt.plot(steps, mean_ious, '-o', markersize=2, alpha=0.7, color='orange')
plt.title('Mean IoU')
plt.xlabel('Steps')
plt.ylabel('IoU')
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.savefig('training_metrics.png')
plt.show()
# Out:
# Total Images: 5428, Total Masks: 5428
# Some weights of SegformerForSemanticSegmentation were not initialized from the model checkpoint at nvidia/mit-b0 and are newly initialized: ['decode_head.batch_norm.bias', 'decode_head.batch_norm.num_batches_tracked', 'decode_head.batch_norm.running_mean', 'decode_head.batch_norm.running_var', 'decode_head.batch_norm.weight', 'decode_head.classifier.bias', 'decode_head.classifier.weight', 'decode_head.linear_c.0.proj.bias', 'decode_head.linear_c.0.proj.weight', 'decode_head.linear_c.1.proj.bias', 'decode_head.linear_c.1.proj.weight', 'decode_head.linear_c.2.proj.bias', 'decode_head.linear_c.2.proj.weight', 'decode_head.linear_c.3.proj.bias', 'decode_head.linear_c.3.proj.weight', 'decode_head.linear_fuse.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading builder script:   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# Epoch 1
#   0%|          | 0/1086 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/datasets/features/image.py:347: UserWarning: Downcasting array dtype int64 to int32 to be compatible with 'Pillow'
#   warnings.warn(f"Downcasting array dtype {dtype} to {dest_dtype} to be compatible with 'Pillow'")
# Step 0 | Loss: 0.6967 | Mean IoU: 0.1438
# Step 100 | Loss: 0.2505 | Mean IoU: 0.8794
# Step 200 | Loss: 0.2090 | Mean IoU: 0.8274
# Step 300 | Loss: 0.1458 | Mean IoU: 0.8906
# Step 400 | Loss: 0.1372 | Mean IoU: 0.8826
# Step 500 | Loss: 0.0763 | Mean IoU: 0.9357
# Step 600 | Loss: 0.1016 | Mean IoU: 0.8801
# Step 700 | Loss: 0.0670 | Mean IoU: 0.9247
# Step 800 | Loss: 0.0714 | Mean IoU: 0.8945
# Step 900 | Loss: 0.0664 | Mean IoU: 0.9129
# Step 1000 | Loss: 0.0586 | Mean IoU: 0.9291
# Epoch 1 | Average Loss: 0.1393
#
# Epoch 2
#   0%|          | 0/1086 [00:00<?, ?it/s]
# Step